# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter

headers_to_split_on = [
    ("#", "h1"),
    ("##", "h2"),
    # ("###", "h3"),
    # ("####", "h4"),
]

splitter = MarkdownHeaderTextSplitter(
    headers_to_split_on=headers_to_split_on,
    strip_headers=False,  # header text goes to metadata only
)

# %%
from pathlib import Path

folder_path = Path("../data/processed")

for idx, item in enumerate(folder_path.iterdir()):
    if item.is_file():
        with open(item, "r", encoding="utf-8") as file:
            markdown_content = file.read()
        chunks = splitter.split_text(markdown_content)
    print(f"Document no. {idx + 1} chunked.")
# Out:
# Document no. 1 chunked.
# Document no. 2 chunked.
# Document no. 3 chunked.
# Document no. 4 chunked.
# Document no. 5 chunked.
# Document no. 6 chunked.
# Document no. 7 chunked.
